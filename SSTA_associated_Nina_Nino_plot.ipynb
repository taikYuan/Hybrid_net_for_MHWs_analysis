# %%
import numpy as np

# %%
nino_data1 = np.load(r'D:\heat_wave\atlantic\EINO_NINA_plot\Nino_data_clim.npz')
nino_data1.files
# Out:
# ['target_Nino_data_clim_82_83',
#  'target_Nino_data_clim_87_88',
#  'target_Nino_data_clim_97_98',
#  'target_Nino_data_clim_02_03',
#  'target_Nino_data_clim_04_05',
#  'target_Nino_data_clim_09_10',
#  'target_Nino_data_clim_15_16',
#  'target_Nino_data_clim_18_19']

# %%
#气候态平均数据
target_Nino_data_clim_82_83 = nino_data1['target_Nino_data_clim_82_83'][:]
target_Nino_data_clim_87_88 = nino_data1['target_Nino_data_clim_87_88'][:]
target_Nino_data_clim_97_98 = nino_data1['target_Nino_data_clim_97_98'][:]
target_Nino_data_clim_02_03 = nino_data1['target_Nino_data_clim_02_03'][:]
target_Nino_data_clim_04_05 = nino_data1['target_Nino_data_clim_04_05'][:]
target_Nino_data_clim_09_10 = nino_data1['target_Nino_data_clim_09_10'][:]
target_Nino_data_clim_15_16 = nino_data1['target_Nino_data_clim_15_16'][:]
target_Nino_data_clim_18_19 = nino_data1['target_Nino_data_clim_18_19'][:]

# %%
data_clim_nino = np.mean([target_Nino_data_clim_82_83, target_Nino_data_clim_87_88,
                              target_Nino_data_clim_97_98, target_Nino_data_clim_02_03, 
                              target_Nino_data_clim_04_05, target_Nino_data_clim_09_10,
                              target_Nino_data_clim_15_16,target_Nino_data_clim_18_19], axis = 0)
# data_clim_nino = np.mean([target_Nino_data_clim_82_83, target_Nino_data_clim_87_88,
#                               target_Nino_data_clim_97_98, target_Nino_data_clim_02_03,
#                           target_Nino_data_clim_09_10,
#                               target_Nino_data_clim_15_16,target_Nino_data_clim_18_19], axis = 0)
data_clim_nino.shape
np.mean(data_clim_nino)
# Out:
# 23.98290794396158

# %%
nino_data2 = np.load(r'D:\heat_wave\atlantic\EINO_NINA_plot\Nino_data_with_MHW.npz')
nino_data2.files
# Out:
# ['target_Nino_data_82_83',
#  'target_Nino_data_87_88',
#  'target_Nino_data_97_98',
#  'target_Nino_data_02_03',
#  'target_Nino_data_04_05',
#  'target_Nino_data_09_10',
#  'target_Nino_data_15_16',
#  'target_Nino_data_18_19']

# %%
#data_with_MHW
target_Nino_data_82_83 = nino_data2['target_Nino_data_82_83'][:]
target_Nino_data_87_88 = nino_data2['target_Nino_data_87_88'][:]
target_Nino_data_97_98 = nino_data2['target_Nino_data_97_98'][:]
target_Nino_data_02_03 = nino_data2['target_Nino_data_02_03'][:]
target_Nino_data_04_05 = nino_data2['target_Nino_data_04_05'][:]
target_Nino_data_09_10 = nino_data2['target_Nino_data_09_10'][:]
target_Nino_data_15_16 = nino_data2['target_Nino_data_15_16'][:]
target_Nino_data_18_19 = nino_data2['target_Nino_data_18_19'][:]

# %%
data_with_MHW_nino = np.mean([target_Nino_data_82_83, target_Nino_data_87_88,
                              target_Nino_data_97_98, target_Nino_data_02_03, 
                              target_Nino_data_04_05, target_Nino_data_09_10,
                              target_Nino_data_15_16,target_Nino_data_18_19], axis = 0)
# data_with_MHW_nino = np.mean([target_Nino_data_82_83, target_Nino_data_87_88,
#                               target_Nino_data_97_98, target_Nino_data_02_03, 
#                                target_Nino_data_09_10,
#                               target_Nino_data_15_16,target_Nino_data_18_19], axis = 0)
np.mean(data_with_MHW_nino)
# data_with_MHW_nino.shape
data_with_MHW_nino = np.mean(data_with_MHW_nino, axis = (1,2))
np.mean(data_with_MHW_nino)
data_with_MHW_nino.shape
# Out:
# (730,)

# %%
nino_data3 = np.load(r'D:\heat_wave\atlantic\EINO_NINA_plot\Nino_data_without_MHW.npz')
nino_data3.files
# Out:
# ['target_Nino_data_without_data_82_83',
#  'target_Nino_data_without_data_87_88',
#  'target_Nino_data_without_data_97_98',
#  'target_Nino_data_without_data_02_03',
#  'target_Nino_data_without_data_04_05',
#  'target_Nino_data_without_data_09_10',
#  'target_Nino_data_without_data_15_16',
#  'target_Nino_data_without_data_18_19']

# %%
#data_without_MHW
target_Nino_data_without_data_82_83 = nino_data3['target_Nino_data_without_data_82_83'][:]
target_Nino_data_without_data_87_88 = nino_data3['target_Nino_data_without_data_87_88'][:]
target_Nino_data_without_data_97_98 = nino_data3['target_Nino_data_without_data_97_98'][:]
target_Nino_data_without_data_02_03 = nino_data3['target_Nino_data_without_data_02_03'][:]
target_Nino_data_without_data_04_05 = nino_data3['target_Nino_data_without_data_04_05'][:]
target_Nino_data_without_data_09_10 = nino_data3['target_Nino_data_without_data_09_10'][:]
target_Nino_data_without_data_15_16 = nino_data3['target_Nino_data_without_data_15_16'][:]
target_Nino_data_without_data_18_19 = nino_data3['target_Nino_data_without_data_18_19'][:]

# %%
data_without_MHW_nino = np.nanmean([target_Nino_data_without_data_82_83, target_Nino_data_without_data_87_88,
                              target_Nino_data_without_data_97_98, target_Nino_data_without_data_02_03, 
                              target_Nino_data_without_data_04_05, target_Nino_data_without_data_09_10,
                              target_Nino_data_without_data_15_16, 
                                    target_Nino_data_without_data_18_19], axis = 0)
# data_without_MHW_nino = np.nanmean([target_Nino_data_without_data_82_83, target_Nino_data_without_data_87_88,
#                               target_Nino_data_without_data_97_98, target_Nino_data_without_data_02_03, 
#                                target_Nino_data_without_data_09_10,
#                               target_Nino_data_without_data_15_16, 
#                                     target_Nino_data_without_data_18_19], axis = 0)
data_without_MHW_nino.shape
data_without_MHW_nino = np.mean(data_without_MHW_nino, axis = (1,2))
np.mean(data_without_MHW_nino)
# data_without_MHW_nino.shape
# Out:
# 23.998112

# %%
#对data_with_MHW_nino进行120-day running mean操作
data_with_MHW_nino = data_with_MHW_nino
# 移动平均窗口大小 
window_size = 60 
# 计算移动平均 
weights = np.repeat(1.0, window_size) / window_size 
smoothed_data = np.convolve(data_with_MHW_nino, weights, 'valid') #
# 输出平滑后的数据 
print(smoothed_data.shape)
# Out:
# (671,)

# %%
window_size = 60
data_with_MHW_nino1 = np.copy(data_with_MHW_nino)
for i in range(window_size//2, len(data_with_MHW_nino)-window_size//2): 
    data_with_MHW_nino1[i] = np.mean(data_with_MHW_nino1[i-window_size//2:i+window_size//2+1])

data_with_MHW_nino_running = data_with_MHW_nino1

# %%
# 对气候数据平滑

data_with_MHW_nino = data_with_MHW_nino
# 移动平均窗口大小 
window_size = 90 
# 计算移动平均 
weights = np.repeat(1.0, window_size) / window_size 
smoothed_data1 = np.convolve(data_clim_nino, weights, 'valid') #
# 输出平滑后的数据 
print(smoothed_data1.shape)
# Out:
# (641,)

# %%
#所有数据进行10day移动平均
window_size = 10
weights = np.repeat(1.0, window_size) / window_size 

data_with_MHW_nino1 = np.convolve(data_with_MHW_nino, weights, 'valid') #
data_without_MHW_nino1 = np.convolve(data_without_MHW_nino, weights, 'valid') #
data_clim_nino1 = np.convolve(data_clim_nino, weights, 'valid') #

# %%
SSTA_associated_Nino.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_39628/3204011970.py in <module>
# ----> 1 SSTA_associated_Nino.shape
#
# NameError: name 'SSTA_associated_Nino' is not defined

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

y1=data_with_MHW_nino -  SSTA_associated_Nino# np.array
y2= data_without_MHW_nino - data_clim_nino# pd.Series
y3 = data_with_MHW_nino_running  - data_clim_nino
labels = ['Jan[0]','Apr[0]','Jul[0]','Oct[0]','Jan[1]','Apr[1]','Jul[1]','Oct[1]','']

#设置横坐标位置
plt.figure(figsize = (8,4), dpi = 300)
x_positions = np.linspace(0, len(y1)-1, 9)


plt.plot(y1,color = '#D62728', label='With MHWs')
plt.plot(y2,color = '#1F77B4', label='Without MHWs')  # x可省略,默认[0,1..,N-1]递增
plt.plot(y3,color = '#885624', label='Without MHWs (120-day running mean)', linestyle = '-.')  # x可省略,默认[0,1..,N-1]递增
plt.xticks(x_positions, labels)
plt.legend(frameon=False, loc = 'upper left')
# plt.xlabel('Time')
plt.xlim(0,730)
plt.ylabel('South Atlantic SSTA (℃)')

#添加竖线
plt.axvline(x=243,color = '#7F7F7F', linestyle = '-')
plt.axvline(x=396,color = '#7F7F7F', linestyle = '-')

#添加文字
plt.text(263,-0.35,'EI Nino-P1',fontsize = 14, color = '#7F7F7F')


#添加竖线
plt.axvline(x=485,color = '#7F7F7F', linestyle = '-')
plt.axvline(x=608,color = '#7F7F7F', linestyle = '-')

#添加文字
plt.text(490,-0.35,'EI Nino-P2',fontsize = 14, color = '#7F7F7F')

plt.show() # plt.show()前可加多个plt.plot(),画在同一张图上

# %%
nina_data1 = np.load(r'D:\heat_wave\atlantic\EINO_NINA_plot\Nina_data_clim.npz')
nina_data1.files
# Out:
# ['target_Nina_data_clim_83_84',
#  'target_Nina_data_clim_98_99',
#  'target_Nina_data_clim_05_06',
#  'target_Nina_data_clim_07_08',
#  'target_Nina_data_clim_11_12',
#  'target_Nina_data_clim_16_17',
#  'target_Nina_data_clim_20_21']

# %%
#气候态平均数据
target_Nina_data_clim_83_84 = nina_data1['target_Nina_data_clim_83_84'][:]
target_Nina_data_clim_98_99 = nina_data1['target_Nina_data_clim_98_99'][:]
target_Nina_data_clim_05_06 = nina_data1['target_Nina_data_clim_05_06'][:]
target_Nina_data_clim_07_08 = nina_data1['target_Nina_data_clim_07_08'][:]
target_Nina_data_clim_11_12 = nina_data1['target_Nina_data_clim_11_12'][:]
target_Nina_data_clim_16_17 = nina_data1['target_Nina_data_clim_16_17'][:]
target_Nina_data_clim_20_21 = nina_data1['target_Nina_data_clim_20_21'][:]

# %%
data_clim_nina = np.mean([target_Nina_data_clim_83_84, target_Nina_data_clim_98_99,
                         target_Nina_data_clim_05_06, target_Nina_data_clim_07_08, 
                         target_Nina_data_clim_11_12, target_Nina_data_clim_16_17, 
                         target_Nina_data_clim_20_21], axis = 0)
data_clim_nina.shape
np.mean(data_clim_nina)
# Out:
# 23.98290794396158

# %%
nina_data2 = np.load(r'D:\heat_wave\atlantic\EINO_NINA_plot\Nina_data_with_MHW.npz')
nina_data2.files
# Out:
# ['target_Nina_data_83_84',
#  'target_Nina_data_98_99',
#  'target_Nina_data_05_06',
#  'target_Nina_data_07_08',
#  'target_Nina_data_11_12',
#  'target_Nina_data_16_17',
#  'target_Nina_data_20_21']

# %%
#data_with_MHW
target_Nina_data_83_84 = nina_data2['target_Nina_data_83_84'][:]
target_Nina_data_98_99 = nina_data2['target_Nina_data_98_99'][:]
target_Nina_data_05_06 = nina_data2['target_Nina_data_05_06'][:]
target_Nina_data_07_08 = nina_data2['target_Nina_data_07_08'][:]
target_Nina_data_11_12 = nina_data2['target_Nina_data_11_12'][:]
target_Nina_data_16_17 = nina_data2['target_Nina_data_16_17'][:]
target_Nina_data_20_21 = nina_data2['target_Nina_data_20_21'][:]

# %%
data_with_MHW_nina = np.mean([target_Nina_data_83_84, target_Nina_data_98_99, 
                             target_Nina_data_05_06, target_Nina_data_07_08, target_Nina_data_11_12, 
                             target_Nina_data_16_17, target_Nina_data_20_21], axis = 0)
np.mean(data_with_MHW_nina)
# data_with_MHW_nino.shape
data_with_MHW_nina = np.mean(data_with_MHW_nina, axis = (1,2))

# %%
window_size = 60
data_with_MHW_nina1 = np.copy(data_with_MHW_nina)
for i in range(window_size//2, len(data_with_MHW_nina)-window_size//2): 
    data_with_MHW_nina1[i] = np.mean(data_with_MHW_nina1[i-window_size//2:i+window_size//2+1])

data_with_MHW_nina_running = data_with_MHW_nina1

# %%
nina_data3 = np.load(r'D:\heat_wave\atlantic\EINO_NINA_plot\Nina_data_without_MHW.npz')
nina_data3.files
# Out:
# ['target_Nina_data_without_data_83_84',
#  'target_Nina_data_without_data_98_99',
#  'target_Nina_data_without_data_05_06',
#  'target_Nina_data_without_data_07_08',
#  'target_Nina_data_without_data_11_12',
#  'target_Nina_data_without_data_16_17',
#  'target_Nina_data_without_data_20_21']

# %%
#data_without_MHW
target_Nina_data_without_data_83_84 = nina_data3['target_Nina_data_without_data_83_84'][:]
target_Nina_data_without_data_98_99 = nina_data3['target_Nina_data_without_data_98_99'][:]
target_Nina_data_without_data_05_06 = nina_data3['target_Nina_data_without_data_05_06'][:]
target_Nina_data_without_data_07_08 = nina_data3['target_Nina_data_without_data_07_08'][:]
target_Nina_data_without_data_11_12 = nina_data3['target_Nina_data_without_data_11_12'][:]
target_Nina_data_without_data_16_17 = nina_data3['target_Nina_data_without_data_16_17'][:]
target_Nina_data_without_data_20_21 = nina_data3['target_Nina_data_without_data_20_21'][:]

# %%
data_without_MHW_nina = np.nanmean([target_Nina_data_without_data_83_84, target_Nina_data_without_data_98_99,
                                   target_Nina_data_without_data_05_06, target_Nina_data_without_data_07_08, 
                                   target_Nina_data_without_data_11_12, target_Nina_data_without_data_16_17, 
                                   target_Nina_data_without_data_20_21], axis = 0)
data_without_MHW_nina.shape
data_without_MHW_nina = np.mean(data_without_MHW_nina, axis = (1,2))
np.mean(data_without_MHW_nina)
# data_without_MHW_nino.shape
# Out:
# 23.952368

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

y1=data_with_MHW_nina -  data_clim_nina# np.array
y2= data_without_MHW_nina - data_clim_nina# pd.Series
y3= data_with_MHW_nina_running - data_clim_nina# pd.Series
labels = ['Jan[0]','Apr[0]','Jul[0]','Oct[0]','Jan[1]','Apr[1]','Jul[1]','Oct[1]','']

#设置横坐标位置
x_positions = np.linspace(0, len(y1)-1, 9)

plt.figure(figsize = (8,4), dpi = 300)

plt.plot(y1,color = '#D62728', label='With MHWs')
plt.plot(y2,color = '#1F77B4', label='Without MHWs')  # x可省略,默认[0,1..,N-1]递增
plt.plot(y3,color = '#1F77B4', label='Without MHWs 120 running')  # x可省略,默认[0,1..,N-1]递增
plt.xticks(x_positions, labels)
plt.legend(frameon=False, loc = 'upper left')
# plt.xlabel('Time')
plt.xlim(0,730)
plt.ylim(-0.4,0.4)
plt.yticks([-0.4,-0.2,0,0.2,0.4])
plt.ylabel('South Atlantic SSTA (℃)')

#添加竖线
plt.axvline(x=396,color = '#7F7F7F', linestyle = '-')
plt.axvline(x=485,color = '#7F7F7F', linestyle = '-')



#添加文字
plt.text(398,-0.3,'La Nina-P1',fontsize = 10, color = '#7F7F7F')



plt.show() # plt.show()前可加多个plt.plot(),画在同一张图上

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 第一个子图
y1 = data_with_MHW_nino - data_clim_nino  # np.array
y2 = data_without_MHW_nino - data_clim_nino  # pd.Series
y3 = data_with_MHW_nino_running  - data_clim_nino
# y3 = y3
labels = ['Jan[0]', 'Apr[0]', 'Jul[0]', 'Oct[0]', 'Jan[1]', 'Apr[1]', 'Jul[1]', 'Oct[1]', '']

# 设置横坐标位置
x_positions = np.linspace(0, len(y1) - 1, 9)

fig, (ax1, ax2) = plt.subplots(nrows=2, figsize=(8, 8), dpi=300, gridspec_kw = {'hspace':0.2})

ax1.plot(y1, color='#D62728', label='With MHWs')
ax1.plot(y3, color='#1C1C1C', label='With MHWs (60-day running mean)', linestyle='--')
ax1.plot(y2, color='#1F77B4', label='Without MHWs')

ax1.set_xticks(x_positions)
ax1.set_xticklabels(labels)
ax1.legend(frameon=False, loc='upper left', ncol = 2, columnspacing = -10.2)
ax1.set_xlim(0, 730)
# ax1.set_xlabel('Time')
ax1.set_ylabel('South Atlantic SSTA (℃)')

# 添加竖线
ax1.axvline(x=243, color='#7F7F7F', linestyle='-')
ax1.axvline(x=396, color='#7F7F7F', linestyle='-')

# 添加文字
ax1.text(263, -0.35, 'EI Nino-P1', fontsize=14, color='#7F7F7F')

#添加竖线
ax1.axvline(x=485,color = '#7F7F7F', linestyle = '-')
ax1.axvline(x=608,color = '#7F7F7F', linestyle = '-')

#添加文字
ax1.text(488,-0.35,'EI Nino-P2',fontsize = 14, color = '#7F7F7F')

ax1.set_title('(a) South Atlantic associated with EI Nino', loc = 'left')

# 第二个子图
y1 = data_with_MHW_nina - data_clim_nina  # np.array
y2 = data_without_MHW_nina - data_clim_nina  # pd.Series
y3 = data_with_MHW_nina_running  - data_clim_nina

labels = ['Jan[0]', 'Apr[0]', 'Jul[0]', 'Oct[0]', 'Jan[1]', 'Apr[1]', 'Jul[1]', 'Oct[1]', '']

# 设置横坐标位置
x_positions = np.linspace(0, len(y1) - 1, 9)

ax2.plot(y1, color='#D62728', label='With MHWs')
ax2.plot(y3, color='#1C1C1C', label='With MHWs (60-day running mean)', linestyle='--' )
ax2.plot(y2, color='#1F77B4', label='Without MHWs')

ax2.set_xticks(x_positions)
ax2.set_xticklabels(labels)
ax2.legend(frameon=False, loc='upper left', ncol = 2, labelspacing = 0.5, columnspacing = -10.2)
ax2.set_xlim(0, 730)
ax2.set_ylim(-0.4, 0.4)
ax2.set_yticks([-0.4, -0.2, 0, 0.2, 0.4])
# ax2.set_xlabel('Time')
ax2.set_ylabel('South Atlantic SSTA (℃)')

# 添加竖线
ax2.axvline(x=120, color='#7F7F7F', linestyle='-')
ax2.axvline(x=243, color='#7F7F7F', linestyle='-')

# 添加文字
ax2.text(120, -0.3, 'La Nina-P1', fontsize=14, color='#7F7F7F')

ax2.set_title('(b) South Atlantic associated with La Nina', loc = 'left')
# ax2.axvline(x=200, color='#7F7F7F', linestyle='-')
plt.show()

# %%
import pandas as pd

start_date = pd.to_datetime('1993-01-01') # 假设起始时间为2022年1月1日
index_9_1 = (pd.to_datetime('1993-9-01') - start_date).days  #588
index_9_1
# Out:
# 243

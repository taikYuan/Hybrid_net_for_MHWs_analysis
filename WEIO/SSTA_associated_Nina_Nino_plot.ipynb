# %%
import numpy as np

# %%
nino_data1 = np.load(r'D:\heat_wave\WEIO\expand_WEIO\EINO_NINA_plot\Nino_data_clim.npz')
nino_data1.files
# Out:
# ['target_Nino_data_clim_82_83',
#  'target_Nino_data_clim_87_88',
#  'target_Nino_data_clim_97_98',
#  'target_Nino_data_clim_06_07',
#  'target_Nino_data_clim_09_10',
#  'target_Nino_data_clim_14_15',
#  'target_Nino_data_clim_15_16',
#  'target_Nino_data_clim_18_19']

# %%
#气候态平均数据
target_Nino_data_clim_82_83 = nino_data1['target_Nino_data_clim_82_83'][:]
target_Nino_data_clim_87_88 = nino_data1['target_Nino_data_clim_87_88'][:]
target_Nino_data_clim_97_98 = nino_data1['target_Nino_data_clim_97_98'][:]
target_Nino_data_clim_06_07 = nino_data1['target_Nino_data_clim_06_07'][:]
target_Nino_data_clim_09_10 = nino_data1['target_Nino_data_clim_09_10'][:]
target_Nino_data_clim_14_15 = nino_data1['target_Nino_data_clim_14_15'][:]
target_Nino_data_clim_15_16 = nino_data1['target_Nino_data_clim_15_16'][:]
target_Nino_data_clim_18_19 = nino_data1['target_Nino_data_clim_18_19'][:]

# %%
data_clim_nino = np.mean([target_Nino_data_clim_82_83, target_Nino_data_clim_87_88,
                              target_Nino_data_clim_97_98, target_Nino_data_clim_06_07, 
                              target_Nino_data_clim_09_10, target_Nino_data_clim_14_15,
                              target_Nino_data_clim_15_16,target_Nino_data_clim_18_19], axis = 0)

data_clim_nino.shape
np.mean(data_clim_nino)
# Out:
# 28.44008612049084

# %%
nino_data2 = np.load(r'D:\heat_wave\WEIO\expand_WEIO\EINO_NINA_plot\Nino_data_with_MHW.npz')
nino_data2.files
# Out:
# ['target_Nino_data_82_83',
#  'target_Nino_data_87_88',
#  'target_Nino_data_97_98',
#  'target_Nino_data_06_07',
#  'target_Nino_data_09_10',
#  'target_Nino_data_14_15',
#  'target_Nino_data_15_16',
#  'target_Nino_data_18_19']

# %%
#data_with_MHW
target_Nino_data_82_83 = nino_data2['target_Nino_data_82_83'][:]
target_Nino_data_87_88 = nino_data2['target_Nino_data_87_88'][:]
target_Nino_data_97_98 = nino_data2['target_Nino_data_97_98'][:]
target_Nino_data_06_07 = nino_data2['target_Nino_data_06_07'][:]
target_Nino_data_09_10 = nino_data2['target_Nino_data_09_10'][:]
target_Nino_data_14_15 = nino_data2['target_Nino_data_14_15'][:]
target_Nino_data_15_16 = nino_data2['target_Nino_data_15_16'][:]
target_Nino_data_18_19 = nino_data2['target_Nino_data_18_19'][:]

# %%
data_with_MHW_nino = np.mean([target_Nino_data_82_83, target_Nino_data_87_88,
                              target_Nino_data_97_98, target_Nino_data_06_07, 
                              target_Nino_data_09_10, target_Nino_data_14_15, 
                              target_Nino_data_15_16,target_Nino_data_18_19], axis = 0)
# data_with_MHW_nino = np.mean([target_Nino_data_82_83, target_Nino_data_87_88,
#                               target_Nino_data_97_98, target_Nino_data_02_03, 
#                                target_Nino_data_09_10,
#                               target_Nino_data_15_16,target_Nino_data_18_19], axis = 0)
np.mean(data_with_MHW_nino)
# data_with_MHW_nino.shape
data_with_MHW_nino = np.mean(data_with_MHW_nino, axis = (1,2))
np.mean(data_with_MHW_nino)
data_with_MHW_nino.shape
# Out:
# (730,)

# %%
nino_data3 = np.load(r'D:\heat_wave\WEIO\expand_WEIO\EINO_NINA_plot\Nino_data_without_MHW.npz')
nino_data3.files
# Out:
# ['target_Nino_data_without_data_82_83',
#  'target_Nino_data_without_data_87_88',
#  'target_Nino_data_without_data_97_98',
#  'target_Nino_data_without_data_06_07',
#  'target_Nino_data_without_data_09_10',
#  'target_Nino_data_without_data_14_15',
#  'target_Nino_data_without_data_15_16',
#  'target_Nino_data_without_data_18_19']

# %%
#data_without_MHW
target_Nino_data_without_data_82_83 = nino_data3['target_Nino_data_without_data_82_83'][:]
target_Nino_data_without_data_87_88 = nino_data3['target_Nino_data_without_data_87_88'][:]
target_Nino_data_without_data_97_98 = nino_data3['target_Nino_data_without_data_97_98'][:]
target_Nino_data_without_data_06_07 = nino_data3['target_Nino_data_without_data_06_07'][:]
target_Nino_data_without_data_09_10 = nino_data3['target_Nino_data_without_data_09_10'][:]
target_Nino_data_without_data_14_15 = nino_data3['target_Nino_data_without_data_14_15'][:]
target_Nino_data_without_data_15_16 = nino_data3['target_Nino_data_without_data_15_16'][:]
target_Nino_data_without_data_18_19 = nino_data3['target_Nino_data_without_data_18_19'][:]

# %%
data_without_MHW_nino = np.nanmean([target_Nino_data_without_data_82_83, target_Nino_data_without_data_87_88,
                              target_Nino_data_without_data_97_98, target_Nino_data_without_data_06_07, 
                              target_Nino_data_without_data_09_10, target_Nino_data_without_data_14_15, 
                              target_Nino_data_without_data_15_16, 
                                    target_Nino_data_without_data_18_19], axis = 0)
# data_without_MHW_nino = np.nanmean([target_Nino_data_without_data_82_83, target_Nino_data_without_data_87_88,
#                               target_Nino_data_without_data_97_98, target_Nino_data_without_data_02_03, 
#                                target_Nino_data_without_data_09_10,
#                               target_Nino_data_without_data_15_16, 
#                                     target_Nino_data_without_data_18_19], axis = 0)
data_without_MHW_nino.shape
data_without_MHW_nino = np.mean(data_without_MHW_nino, axis = (1,2))
np.mean(data_without_MHW_nino)
# data_without_MHW_nino.shape
# Out:
# 28.557396

# %%
#对data_with_MHW_nino进行120-day running mean操作
data_with_MHW_nino = data_with_MHW_nino
# 移动平均窗口大小 
window_size = 60 
# 计算移动平均 
weights = np.repeat(1.0, window_size) / window_size 
smoothed_data = np.convolve(data_with_MHW_nino, weights, 'valid') #
# 输出平滑后的数据 
print(smoothed_data.shape)
# Out:
# (671,)

# %%
# 对气候数据平滑

data_with_MHW_nino = data_with_MHW_nino
# 移动平均窗口大小 
window_size = 60 
# 计算移动平均 
weights = np.repeat(1.0, window_size) / window_size 
smoothed_data1 = np.convolve(data_clim_nino, weights, 'valid') #
# 输出平滑后的数据 
print(smoothed_data1.shape)
# Out:
# (671,)

# %%
window_size = 60
data_with_MHW_nino1 = np.copy(data_with_MHW_nino)
for i in range(window_size//2, len(data_with_MHW_nino)-window_size//2): 
    data_with_MHW_nino1[i] = np.mean(data_with_MHW_nino1[i-window_size//2:i+window_size//2+1])

data_with_MHW_nino_running = data_with_MHW_nino1

# %%
window_size = 10
data_with_MHW_nino = np.copy(data_with_MHW_nino)
for i in range(window_size//2, len(data_with_MHW_nino)-window_size//2): 
    data_with_MHW_nino[i] = np.mean(data_with_MHW_nino[i-window_size//2:i+window_size//2+1])

data_with_MHW_nino = data_with_MHW_nino

# %%
window_size = 10
data_without_MHW_nino = np.copy(data_without_MHW_nino)
for i in range(window_size//2, len(data_without_MHW_nino)-window_size//2): 
    data_without_MHW_nino[i] = np.mean(data_without_MHW_nino[i-window_size//2:i+window_size//2+1])

data_without_MHW_nino = data_without_MHW_nino

# %%
"""以下是NOAA原始文件的SSTA数据，和预测的SSTA做差为误差"""
# Out:
# '以下是NOAA原始文件的SSTA数据，和预测的SSTA做差为误差'

# %%
nino_noaa2 = np.load(r'D:\heat_wave\WEIO\expand_WEIO\EINO_NINA_plot\Nino_noaa_ssta_with_MHW.npz')
nino_noaa2.files
# Out:
# ['target_noaa_ssta_82_83',
#  'target_noaa_ssta_87_88',
#  'target_noaa_ssta_97_98',
#  'target_noaa_ssta_06_07',
#  'target_noaa_ssta_09_10',
#  'target_noaa_ssta_14_15',
#  'target_noaa_ssta_15_16',
#  'target_noaa_ssta_18_19']

# %%
#ssta_with_MHW
target_Nino_noaa_ssta_82_83 = nino_noaa2['target_noaa_ssta_82_83'][:]
target_Nino_noaa_ssta_87_88 = nino_noaa2['target_noaa_ssta_82_83'][:]
target_Nino_noaa_ssta_97_98 = nino_noaa2['target_noaa_ssta_97_98'][:]
target_Nino_noaa_ssta_06_07 = nino_noaa2['target_noaa_ssta_97_98'][:]
target_Nino_noaa_ssta_09_10 = nino_noaa2['target_noaa_ssta_09_10'][:]
target_Nino_noaa_ssta_14_15 = nino_noaa2['target_noaa_ssta_14_15'][:]
target_Nino_noaa_ssta_15_16 = nino_noaa2['target_noaa_ssta_15_16'][:]
target_Nino_noaa_ssta_18_19 = nino_noaa2['target_noaa_ssta_18_19'][:]

# %%
noaa_ssta_with_MHW_nino = np.mean([target_Nino_noaa_ssta_82_83, target_Nino_noaa_ssta_87_88,
                              target_Nino_noaa_ssta_97_98, target_Nino_noaa_ssta_06_07, 
                              target_Nino_noaa_ssta_09_10, target_Nino_noaa_ssta_14_15, 
                              target_Nino_noaa_ssta_15_16,target_Nino_noaa_ssta_18_19], axis = 0)
# data_with_MHW_nino = np.mean([target_Nino_data_82_83, target_Nino_data_87_88,
#                               target_Nino_data_97_98, target_Nino_data_02_03, 
#                                target_Nino_data_09_10,
#                               target_Nino_data_15_16,target_Nino_data_18_19], axis = 0)
np.mean(noaa_ssta_with_MHW_nino)
# data_with_MHW_nino.shape
noaa_ssta_with_MHW_nino = np.mean(noaa_ssta_with_MHW_nino, axis = (1,2))
np.mean(noaa_ssta_with_MHW_nino)
noaa_ssta_with_MHW_nino.shape
# Out:
# (730,)

# %%
nino_noaa3 = np.load(r'D:\heat_wave\WEIO\expand_WEIO\EINO_NINA_plot\Nino_noaa_ssta_without_MHW.npz')
nino_noaa3.files
# Out:
# ['target_Nino_noaa_ssta_without_data_82_83',
#  'target_Nino_noaa_ssta_without_data_87_88',
#  'target_Nino_noaa_ssta_without_data_97_98',
#  'target_Nino_noaa_ssta_without_data_06_07',
#  'target_Nino_noaa_ssta_without_data_09_10',
#  'target_Nino_noaa_ssta_without_data_14_15',
#  'target_Nino_noaa_ssta_without_data_15_16',
#  'target_Nino_noaa_ssta_without_data_18_19']

# %%
#data_without_MHW
target_Nino_noaa_ssta_without_data_82_83 = nino_noaa3['target_Nino_noaa_ssta_without_data_82_83'][:]
target_Nino_noaa_ssta_without_data_87_88 = nino_noaa3['target_Nino_noaa_ssta_without_data_87_88'][:]
target_Nino_noaa_ssta_without_data_97_98 = nino_noaa3['target_Nino_noaa_ssta_without_data_97_98'][:]
target_Nino_noaa_ssta_without_data_06_07 = nino_noaa3['target_Nino_noaa_ssta_without_data_06_07'][:]
target_Nino_noaa_ssta_without_data_09_10 = nino_noaa3['target_Nino_noaa_ssta_without_data_09_10'][:]
target_Nino_noaa_ssta_without_data_14_15 = nino_noaa3['target_Nino_noaa_ssta_without_data_14_15'][:]
target_Nino_noaa_ssta_without_data_15_16 = nino_noaa3['target_Nino_noaa_ssta_without_data_15_16'][:]
target_Nino_noaa_ssta_without_data_18_19 = nino_noaa3['target_Nino_noaa_ssta_without_data_18_19'][:]

# %%
noaa_ssta_without_MHW_nino = np.nanmean([target_Nino_noaa_ssta_without_data_82_83, target_Nino_noaa_ssta_without_data_87_88,
                              target_Nino_noaa_ssta_without_data_97_98, target_Nino_noaa_ssta_without_data_06_07, 
                              target_Nino_noaa_ssta_without_data_09_10, target_Nino_noaa_ssta_without_data_14_15, 
                              target_Nino_noaa_ssta_without_data_15_16, 
                                    target_Nino_noaa_ssta_without_data_18_19], axis = 0)
# data_without_MHW_nino = np.nanmean([target_Nino_data_without_data_82_83, target_Nino_data_without_data_87_88,
#                               target_Nino_data_without_data_97_98, target_Nino_data_without_data_02_03, 
#                                target_Nino_data_without_data_09_10,
#                               target_Nino_data_without_data_15_16, 
#                                     target_Nino_data_without_data_18_19], axis = 0)
noaa_ssta_without_MHW_nino.shape
noaa_ssta_without_MHW_nino = np.mean(noaa_ssta_without_MHW_nino, axis = (1,2))
np.mean(noaa_ssta_without_MHW_nino)
# data_without_MHW_nino.shape
# Out:
# 0.23295136

# %%
window_size = 10
noaa_ssta_with_MHW_nino = np.copy(noaa_ssta_with_MHW_nino)
for i in range(window_size//2, len(noaa_ssta_with_MHW_nino)-window_size//2): 
    noaa_ssta_with_MHW_nino[i] = np.mean(noaa_ssta_with_MHW_nino[i-window_size//2:i+window_size//2+1])

noaa_ssta_with_MHW_nino = noaa_ssta_with_MHW_nino

# %%
window_size = 10
noaa_ssta_without_MHW_nino = np.copy(noaa_ssta_without_MHW_nino)
for i in range(window_size//2, len(noaa_ssta_without_MHW_nino)-window_size//2): 
    noaa_ssta_without_MHW_nino[i] = np.mean(noaa_ssta_without_MHW_nino[i-window_size//2:i+window_size//2+1])

noaa_ssta_without_MHW_nino = noaa_ssta_without_MHW_nino

# %%
window_size = 120
noaa_ssta_with_MHW_nino_120 = np.copy(noaa_ssta_with_MHW_nino)
for i in range(window_size//2, len(noaa_ssta_with_MHW_nino_120)-window_size//2): 
    noaa_ssta_with_MHW_nino_120[i] = np.mean(noaa_ssta_with_MHW_nino_120[i-window_size//2:i+window_size//2+1])

noaa_ssta_with_MHW_nino_120 = noaa_ssta_with_MHW_nino_120

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

y1=noaa_ssta_with_MHW_nino# np.array
y2= noaa_ssta_without_MHW_nino# pd.Series
y3 = noaa_ssta_with_MHW_nino_120
labels = ['Jan[0]','Apr[0]','Jul[0]','Oct[0]','Jan[1]','Apr[1]','Jul[1]','Oct[1]','']

#设置横坐标位置
plt.figure(figsize = (8,4), dpi = 300)
x_positions = np.linspace(0, len(y1)-1, 9)


plt.plot(y1,color = '#D62728', label='With MHWs')
plt.plot(y2,color = '#1F77B4', label='Without MHWs')  # x可省略,默认[0,1..,N-1]递增
plt.plot(y3,color = 'black', label='Without MHWs (120-day running mean)', linestyle = '--')  # x可省略,默认[0,1..,N-1]递增
plt.xticks(x_positions, labels)
plt.legend(frameon=False, loc = 'upper left')
# plt.xlabel('Time')
plt.xlim(0,730)
plt.ylabel('South Atlantic SSTA (℃)')

#添加竖线
plt.axvline(x=243,color = '#7F7F7F', linestyle = '-')
plt.axvline(x=396,color = '#7F7F7F', linestyle = '-')

#添加文字
plt.text(263,-0.35,'EI Nino-P1',fontsize = 14, color = '#7F7F7F')


#添加竖线
plt.axvline(x=485,color = '#7F7F7F', linestyle = '-')
plt.axvline(x=608,color = '#7F7F7F', linestyle = '-')

#添加文字
plt.text(490,-0.35,'EI Nino-P2',fontsize = 14, color = '#7F7F7F')

plt.show() # plt.show()前可加多个plt.plot(),画在同一张图上

# %%
nina_noaa2 = np.load(r'D:\heat_wave\WEIO\expand_WEIO\EINO_NINA_plot\Nina_noaa_ssta_with_MHW.npz')
nina_noaa2.files
# Out:
# ['target_noaa_ssta_83_84',
#  'target_noaa_ssta_98_99',
#  'target_noaa_ssta_07_08',
#  'target_noaa_ssta_10_11',
#  'target_noaa_ssta_16_17',
#  'target_noaa_ssta_20_21']

# %%
#ssta_with_MHW
target_Nina_noaa_ssta_83_84 = nina_noaa2['target_noaa_ssta_83_84'][:708,:,:]
target_Nina_noaa_ssta_98_99 = nina_noaa2['target_noaa_ssta_98_99'][:708,:,:]
target_Nina_noaa_ssta_07_08 = nina_noaa2['target_noaa_ssta_07_08'][:708,:,:]
target_Nina_noaa_ssta_10_11 = nina_noaa2['target_noaa_ssta_10_11'][:708,:,:]
target_Nina_noaa_ssta_16_17 = nina_noaa2['target_noaa_ssta_16_17'][:708,:,:]
target_Nina_noaa_ssta_20_21 = nina_noaa2['target_noaa_ssta_20_21'][:708,:,:]

# %%
target_Nina_noaa_ssta_20_21.shape
# Out:
# (708, 66, 49)

# %%
noaa_ssta_with_MHW_nina = np.mean([target_Nina_noaa_ssta_83_84, 
                                  target_Nina_noaa_ssta_98_99, target_Nina_noaa_ssta_07_08, 
                                  target_Nina_noaa_ssta_10_11, target_Nina_noaa_ssta_16_17, target_Nina_noaa_ssta_20_21], axis = 0)

np.mean(noaa_ssta_with_MHW_nina)
# data_with_MHW_nino.shape
noaa_ssta_with_MHW_nina = np.mean(noaa_ssta_with_MHW_nina, axis = (1,2))
np.mean(noaa_ssta_with_MHW_nina)
noaa_ssta_with_MHW_nina.shape
# Out:
# (708,)

# %%
nina_noaa3 = np.load(r'D:\heat_wave\WEIO\expand_WEIO\EINO_NINA_plot\Nina_noaa_ssta_without_MHW.npz')
nina_noaa3.files
# Out:
# ['target_Nino_noaa_ssta_without_data_83_84',
#  'target_Nino_noaa_ssta_without_data_98_99',
#  'target_Nino_noaa_ssta_without_data_07_08',
#  'target_Nino_noaa_ssta_without_data_10_11',
#  'target_Nino_noaa_ssta_without_data_16_17',
#  'target_Nino_noaa_ssta_without_data_20_21']

# %%
#data_without_MHW
target_Nina_noaa_ssta_without_data_83_84 = nina_noaa3['target_Nino_noaa_ssta_without_data_83_84'][:708,:,:]
target_Nina_noaa_ssta_without_data_98_99 = nina_noaa3['target_Nino_noaa_ssta_without_data_98_99'][:708,:,:]
target_Nina_noaa_ssta_without_data_07_08 = nina_noaa3['target_Nino_noaa_ssta_without_data_07_08'][:708,:,:]
target_Nina_noaa_ssta_without_data_10_11 = nina_noaa3['target_Nino_noaa_ssta_without_data_10_11'][:708,:,:]
target_Nina_noaa_ssta_without_data_16_17 = nina_noaa3['target_Nino_noaa_ssta_without_data_16_17'][:708,:,:]
target_Nina_noaa_ssta_without_data_20_21 = nina_noaa3['target_Nino_noaa_ssta_without_data_20_21'][:708,:,:]

# %%
noaa_ssta_without_MHW_nina = np.nanmean([target_Nina_noaa_ssta_without_data_83_84,
                                        target_Nina_noaa_ssta_without_data_98_99,
                                        target_Nina_noaa_ssta_without_data_07_08,
                                        target_Nina_noaa_ssta_without_data_10_11,
                                        target_Nina_noaa_ssta_without_data_16_17,
                                        target_Nina_noaa_ssta_without_data_20_21], axis = 0)

noaa_ssta_without_MHW_nina.shape
noaa_ssta_without_MHW_nina = np.mean(noaa_ssta_without_MHW_nina, axis = (1,2))
np.mean(noaa_ssta_without_MHW_nina)
# data_without_MHW_nino.shape
# Out:
# 0.27809092

# %%
window_size = 10
noaa_ssta_with_MHW_nina = np.copy(noaa_ssta_with_MHW_nina)
for i in range(window_size//2, len(noaa_ssta_with_MHW_nina)-window_size//2): 
    noaa_ssta_with_MHW_nina[i] = np.mean(noaa_ssta_with_MHW_nina[i-window_size//2:i+window_size//2+1])

noaa_ssta_with_MHW_nina = noaa_ssta_with_MHW_nina

# %%
window_size = 10
noaa_ssta_without_MHW_nina = np.copy(noaa_ssta_without_MHW_nina)
for i in range(window_size//2, len(noaa_ssta_without_MHW_nina)-window_size//2): 
    noaa_ssta_without_MHW_nina[i] = np.mean(noaa_ssta_without_MHW_nina[i-window_size//2:i+window_size//2+1])

noaa_ssta_without_MHW_nina = noaa_ssta_without_MHW_nina

# %%
window_size = 120
noaa_ssta_with_MHW_nina_120 = np.copy(noaa_ssta_with_MHW_nina)
for i in range(window_size//2, len(noaa_ssta_with_MHW_nina_120)-window_size//2): 
    noaa_ssta_with_MHW_nina_120[i] = np.mean(noaa_ssta_with_MHW_nina_120[i-window_size//2:i+window_size//2+1])

noaa_ssta_with_MHW_nina_120 = noaa_ssta_with_MHW_nina_120

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

y1=noaa_ssta_with_MHW_nina# np.array
y2= noaa_ssta_without_MHW_nina# pd.Series
y3 = noaa_ssta_with_MHW_nina_120
labels = ['Jan[0]','Apr[0]','Jul[0]','Oct[0]','Jan[1]','Apr[1]','Jul[1]','Oct[1]','']

#设置横坐标位置
plt.figure(figsize = (8,4), dpi = 300)
x_positions = np.linspace(0, len(y1)-1, 9)


plt.plot(y1,color = '#D62728', label='With MHWs')
plt.plot(y2,color = '#1F77B4', label='Without MHWs')  # x可省略,默认[0,1..,N-1]递增
plt.plot(y3,color = 'black', label='Without MHWs (120-day running mean)', linestyle = '--')  # x可省略,默认[0,1..,N-1]递增
plt.xticks(x_positions, labels)
plt.legend(frameon=False, loc = 'upper left')
# plt.xlabel('Time')
plt.xlim(0,730)
plt.ylabel('South Atlantic SSTA (℃)')

#添加竖线
plt.axvline(x=243,color = '#7F7F7F', linestyle = '-')
plt.axvline(x=396,color = '#7F7F7F', linestyle = '-')

#添加文字
plt.text(263,-0.35,'EI Nino-P1',fontsize = 14, color = '#7F7F7F')


#添加竖线
plt.axvline(x=485,color = '#7F7F7F', linestyle = '-')
plt.axvline(x=608,color = '#7F7F7F', linestyle = '-')

#添加文字
plt.text(490,-0.35,'EI Nino-P2',fontsize = 14, color = '#7F7F7F')

plt.show() # plt.show()前可加多个plt.plot(),画在同一张图上

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, BoundaryNorm
import matplotlib.gridspec as gridspec 
import numpy as np
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\mymylove\Anaconda3\envs\pytorch\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
data1 = np.load(r'D:\heat_wave\WEIO\SLP_SLPA_plot_JJA.npz')
data1.files
# Out:
# ['slp', 'slpa']

# %%
slp_JJA = data1['slp'][:]
slpa_JJA = data1['slpa'][:]

# %%
data2 = np.load(r'D:\heat_wave\WEIO\SLP_SLPA_plot_SON.npz')
data2.files
# Out:
# ['slp', 'slpa']

# %%
slp_SON = data2['slp'][:]
slpa_SON = data2['slpa'][:]

# %%
data3 = np.load(r'D:\heat_wave\WEIO\SLP_SLPA_plot_DJF.npz')
data3.files
# Out:
# ['slp', 'slpa']

# %%
slp_DJF = data3['slp'][:]
slpa_DJF = data3['slpa'][:]

# %%
data4 = np.load(r'D:\heat_wave\WEIO\SLP_SLPA_plot_MAM.npz')
data4.files
# Out:
# ['slp', 'slpa']

# %%
slp_MAM = data4['slp'][:]
slpa_MAM = data4['slpa'][:]

# %%
data5 = np.load(r'D:\heat_wave\WEIO\SSTA_plot_JJA.npz')
data5.files
# Out:
# ['ssta']

# %%
ssta_JJA = data5['ssta'][:]
ssta_JJA.shape
# Out:
# (27, 1)

# %%
data6 = np.load(r'D:\heat_wave\WEIO\SSTA_plot_SON.npz')
data6.files
# Out:
# ['ssta']

# %%
ssta_SON = data6['ssta'][:]
ssta_SON.shape
# Out:
# (27, 1)

# %%
data7 = np.load(r'D:\heat_wave\WEIO\SSTA_plot_DJF.npz')
data7.files
# Out:
# ['ssta']

# %%
ssta_DJF = data7['ssta'][:]
ssta_DJF.shape
# Out:
# (27, 1)

# %%
data8 = np.load(r'D:\heat_wave\WEIO\SSTA_plot_MAM.npz')
data8.files
# Out:
# ['ssta']

# %%
ssta_MAM = data8['ssta'][:]
ssta_MAM.shape
# Out:
# (27, 1)

# %%
y1 = slpa_JJA
y2 = slpa_SON
y3 = slpa_DJF
y4 = slpa_MAM
y5 = ssta_JJA
y6 = ssta_SON
y7 = ssta_DJF
y8 = ssta_MAM

# %%
slpa_JJA.shape
# Out:
# (27, 1)

# %%
import matplotlib.pyplot as plt

# 创建一个图表和一组子图
fig, ax1 = plt.subplots()

# 创建第一个y轴
ax1.set_xlabel('x轴')
ax1.set_ylabel('SLPA')

# 绘制左侧y轴的数据

y1 = slpa_JJA
x = list(range(len(y1)))
ax1.plot(x, y1, color='blue')

# 创建第二个y轴
ax2 = ax1.twinx()
ax2.set_ylabel('SSTA')

# 绘制右侧y轴的数据
y2 = ssta_JJA
ax2.plot(x, y2, color='red')

# 显示图表
plt.show()
# Out:
# C:\Users\mymylove\Anaconda3\envs\pytorch\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 36724 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\mymylove\Anaconda3\envs\pytorch\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 36724 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import matplotlib.pyplot as plt

# 创建一个图表和四个双y轴子图
fig, axs = plt.subplots(nrows=1, ncols=4, sharex=True, sharey=False, dpi = 300, figsize = (16,3))

# 在第一个子图中绘制数据
# axs[0].set_xlabel('x轴')
# axs[0].set_ylabel('SLPA', color='#D62728')
y1 = slpa_JJA
x = list(range(len(y1)))
axs[0].plot(x, y1, color='#D62728')
axs[0].tick_params(axis='y', labelcolor='#D62728')
axs[0].scatter(x,y1,color = '#D62728')
axs[0].scatter(x,y1,color = '#D62728', s = 1)
axs[0].set_title('JJA')

ax2_1 = axs[0].twinx()
# ax2_1.set_ylabel('SSTA', color='#1F77B4')
y2_1 = ssta_JJA
ax2_1.plot(x, y2_1, color='#1F77B4')
ax2_1.tick_params(axis='y', labelcolor='#1F77B4')
ax2_1.scatter(x,y2_1,color = '#1F77B4')
ax2_1.scatter(x,y2_1,color = '#1F77B4', s = 1)

# 在第二个子图中绘制数据
# axs[1].set_xlabel('x轴')
# axs[0].set_ylabel('SLPA', color='#D62728')
y2 = slpa_SON
x = list(range(len(y2)))
axs[1].plot(x, y2, color='#D62728')
axs[1].tick_params(axis='y', labelcolor='#D62728')
axs[1].scatter(x,y2,color = '#D62728')
axs[1].scatter(x,y2,color = '#D62728', s = 1)
axs[1].set_title('SON')

ax2_2 = axs[1].twinx()
# ax2_1.set_ylabel('SSTA', color='#1F77B4')
y2_2 = ssta_SON
ax2_2.plot(x, y2_2, color='#1F77B4')
ax2_2.tick_params(axis='y', labelcolor='#1F77B4')
ax2_2.scatter(x,y2_2,color = '#1F77B4')
ax2_2.scatter(x,y2_2,color = '#1F77B4', s = 1)

# 在第三个子图中绘制数据
# axs[2].set_xlabel('x轴')
# axs[0].set_ylabel('SLPA', color='#D62728')
y3 = slpa_DJF
x = list(range(len(y3)))
axs[2].plot(x, y3, color='#D62728')
axs[2].tick_params(axis='y', labelcolor='#D62728')
axs[2].scatter(x,y3,color = '#D62728')
axs[2].scatter(x,y3,color = '#D62728', s = 1)
axs[2].set_title('DJF')

ax2_3 = axs[2].twinx()
# ax2_1.set_ylabel('SSTA', color='#1F77B4')
y2_3 = ssta_DJF
ax2_3.plot(x, y2_3, color='#1F77B4')
ax2_3.tick_params(axis='y', labelcolor='#1F77B4')
ax2_3.scatter(x,y2_3,color = '#1F77B4')
ax2_3.scatter(x,y2_3,color = '#1F77B4', s = 1)

# 在第四个子图中绘制数据
# axs[3].set_xlabel('x轴')
# axs[0].set_ylabel('SLPA', color='#D62728')
y4 = slpa_MAM
x = list(range(len(y1)))
axs[3].plot(x, y4, color='#D62728')
axs[3].tick_params(axis='y', labelcolor='#D62728')
axs[3].scatter(x,y4,color = '#D62728')
axs[3].scatter(x,y4,color = '#D62728', s = 1)
axs[3].set_title('MAM')

ax2_4 = axs[3].twinx()
# ax2_1.set_ylabel('SSTA', color='#1F77B4')
y2_4 = ssta_MAM
ax2_4.plot(x, y2_4, color='#1F77B4')
ax2_4.tick_params(axis='y', labelcolor='#1F77B4')
ax2_4.scatter(x,y2_4,color = '#1F77B4')
ax2_4.scatter(x,y2_4,color = '#1F77B4', s = 1)


#添加图例
axs[0].plot(x,y1,color = '#D62728', label = 'SLPA (hPa)')
ax2_1.plot(x,y2_1,color = '#1F77B4', label = 'SSTA (℃)')
axs[0].legend(fontsize = 'large',  bbox_to_anchor = (0.59,0.88), frameon = False)
ax2_1.legend(fontsize = 'large', frameon = False)


#添加横线
axs[0].axhline(y=0, color='#D62728', linestyle='--', linewidth=1) 
ax2_1.axhline(y=0, color='#1F77B4', linestyle='-.', linewidth=1)

axs[1].axhline(y=0, color='#D62728', linestyle='--', linewidth=1) 
ax2_2.axhline(y=0, color='#1F77B4', linestyle='-.', linewidth=1)

axs[2].axhline(y=0, color='#D62728', linestyle='--', linewidth=1) 
ax2_3.axhline(y=0, color='#1F77B4', linestyle='-.', linewidth=1)

axs[3].axhline(y=0, color='#D62728', linestyle='--', linewidth=1) 
ax2_4.axhline(y=0, color='#1F77B4', linestyle='-.', linewidth=1)

# 调整子图布局
plt.tight_layout()
# plt.subplots_adjust(left=0.1, right=0.9, bottom=0.1, top=0.9, wspace=0.5, hspace=0.5) 

xticks = np.array([0, 5, 10, 15, 20, 27]) 
axs[0].set_xticks(xticks) 
axs[0].set_xticklabels(['1993', '1998', '2003', '2008', '2013','2019'], fontsize=12)

# 显示图表
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = [u'SimHei']
plt.rcParams['axes.unicode_minus'] = False

# 创建一个图表和四个双y轴子图
fig, axs = plt.subplots(nrows=1, ncols=4, sharex=True, sharey=False, dpi = 300, figsize = (16,3))

# 在第一个子图中绘制数据
# axs[0].set_xlabel('x轴')
# axs[0].set_ylabel('SLPA', color='#D62728')
y1 = slpa_JJA
x = list(range(len(y1)))
axs[0].plot(x, y1, color='#D62728')
axs[0].tick_params(axis='y', labelcolor='#D62728')
axs[0].scatter(x,y1,color = '#D62728')
axs[0].scatter(x,y1,color = '#D62728', s = 1)
axs[0].set_title('六-八月')

ax2_1 = axs[0].twinx()
# ax2_1.set_ylabel('SSTA', color='#1F77B4')
y2_1 = ssta_JJA
ax2_1.plot(x, y2_1, color='#1F77B4')
ax2_1.tick_params(axis='y', labelcolor='#1F77B4')
ax2_1.scatter(x,y2_1,color = '#1F77B4')
ax2_1.scatter(x,y2_1,color = '#1F77B4', s = 1)

# 在第二个子图中绘制数据
# axs[1].set_xlabel('x轴')
# axs[0].set_ylabel('SLPA', color='#D62728')
y2 = slpa_SON
x = list(range(len(y2)))
axs[1].plot(x, y2, color='#D62728')
axs[1].tick_params(axis='y', labelcolor='#D62728')
axs[1].scatter(x,y2,color = '#D62728')
axs[1].scatter(x,y2,color = '#D62728', s = 1)
axs[1].set_title('九-十一月')

ax2_2 = axs[1].twinx()
# ax2_1.set_ylabel('SSTA', color='#1F77B4')
y2_2 = ssta_SON
ax2_2.plot(x, y2_2, color='#1F77B4')
ax2_2.tick_params(axis='y', labelcolor='#1F77B4')
ax2_2.scatter(x,y2_2,color = '#1F77B4')
ax2_2.scatter(x,y2_2,color = '#1F77B4', s = 1)

# 在第三个子图中绘制数据
# axs[2].set_xlabel('x轴')
# axs[0].set_ylabel('SLPA', color='#D62728')
y3 = slpa_DJF
x = list(range(len(y3)))
axs[2].plot(x, y3, color='#D62728')
axs[2].tick_params(axis='y', labelcolor='#D62728')
axs[2].scatter(x,y3,color = '#D62728')
axs[2].scatter(x,y3,color = '#D62728', s = 1)
axs[2].set_title('十二-二月')

ax2_3 = axs[2].twinx()
# ax2_1.set_ylabel('SSTA', color='#1F77B4')
y2_3 = ssta_DJF
ax2_3.plot(x, y2_3, color='#1F77B4')
ax2_3.tick_params(axis='y', labelcolor='#1F77B4')
ax2_3.scatter(x,y2_3,color = '#1F77B4')
ax2_3.scatter(x,y2_3,color = '#1F77B4', s = 1)

# 在第四个子图中绘制数据
# axs[3].set_xlabel('x轴')
# axs[0].set_ylabel('SLPA', color='#D62728')
y4 = slpa_MAM
x = list(range(len(y1)))
axs[3].plot(x, y4, color='#D62728')
axs[3].tick_params(axis='y', labelcolor='#D62728')
axs[3].scatter(x,y4,color = '#D62728')
axs[3].scatter(x,y4,color = '#D62728', s = 1)
axs[3].set_title('三-五月')

ax2_4 = axs[3].twinx()
# ax2_1.set_ylabel('SSTA', color='#1F77B4')
y2_4 = ssta_MAM
ax2_4.plot(x, y2_4, color='#1F77B4')
ax2_4.tick_params(axis='y', labelcolor='#1F77B4')
ax2_4.scatter(x,y2_4,color = '#1F77B4')
ax2_4.scatter(x,y2_4,color = '#1F77B4', s = 1)


#添加图例
axs[0].plot(x,y1,color = '#D62728', label = '压力异常 (hPa)')
ax2_1.plot(x,y2_1,color = '#1F77B4', label = '温度异常 (℃)')
axs[0].legend(fontsize = 'large',  bbox_to_anchor = (0.65,0.88), frameon = False)
ax2_1.legend(fontsize = 'large', frameon = False)


#添加横线
axs[0].axhline(y=0, color='#D62728', linestyle='--', linewidth=1) 
ax2_1.axhline(y=0, color='#1F77B4', linestyle='-.', linewidth=1)

axs[1].axhline(y=0, color='#D62728', linestyle='--', linewidth=1) 
ax2_2.axhline(y=0, color='#1F77B4', linestyle='-.', linewidth=1)

axs[2].axhline(y=0, color='#D62728', linestyle='--', linewidth=1) 
ax2_3.axhline(y=0, color='#1F77B4', linestyle='-.', linewidth=1)

axs[3].axhline(y=0, color='#D62728', linestyle='--', linewidth=1) 
ax2_4.axhline(y=0, color='#1F77B4', linestyle='-.', linewidth=1)

# 调整子图布局
plt.tight_layout()
# plt.subplots_adjust(left=0.1, right=0.9, bottom=0.1, top=0.9, wspace=0.5, hspace=0.5) 

xticks = np.array([0, 5, 10, 15, 20, 27]) 
axs[0].set_xticks(xticks) 
axs[0].set_xticklabels(['1993', '1998', '2003', '2008', '2013','2019'], fontsize=12)

# 显示图表
plt.show()
